# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report

# %%
pd.set_option("display.max_columns",None)

# %%
sonar=pd.read_csv("sonar_data.csv",header=None)

# %%
sonar.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9       10      11      12      13      14      15      16      17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
# ...

# %%
sonar.shape
# Out:
# (208, 61)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
sonar.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
#  20  20      208 non-null    float64
# ...

# %%
sonar.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9           10          11  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.121747    0.134799    0.178003    0.208259    0.236013    0.250221
# ...

# %%
for col in sonar.columns:
    print(sonar[col].value_counts())
# Out:
# 0
# 0.0201    5
# 0.0100    3
# 0.0094    3
# 0.0131    3
# 0.0209    3
#          ..
# 0.0272    1
# 0.0187    1
# 0.0323    1
# 0.0522    1
# 0.0303    1
# Name: count, Length: 177, dtype: int64
# 1
# 0.0523    2
# 0.0582    2
# 0.0453    2
# 0.0173    2
# 0.0309    2
#          ..
# 0.0387    1
# 0.0258    1
# 0.0346    1
# 0.0101    1
# 0.0353    1
# Name: count, Length: 182, dtype: int64
# 2
# 0.0623    2
# 0.0277    2
# 0.0842    2
# 0.0347    2
# 0.0604    2
#          ..
# 0.0329    1
# 0.0488    1
# 0.0168    1
# 0.0180    1
# 0.0490    1
# Name: count, Length: 190, dtype: int64
# 3
# 0.0108    3
# 0.0608    3
# 0.0394    2
# 0.0250    2
# 0.0489    2
#          ..
# 0.0570    1
# 0.0848    1
# 0.0177    1
# 0.0564    1
# 0.0292    1
# Name: count, Length: 181, dtype: int64
# 4
# 0.1158    2
# 0.0647    2
# 0.0597    2
# 0.1615    2
# 0.0630    2
#          ..
# 0.0393    1
# 0.0760    1
# 0.0351    1
# 0.0167    1
# 0.0214    1
# Name: count, Length: 193, dtype: int64
# 5
# ...

# %%
sonar[60].value_counts(normalize=True)
# Out:
# 60
# M    0.533654
# R    0.466346
# Name: proportion, dtype: float64

# %%
sonar
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
sonar[60]=sonar[60].map({"R":0,"M":1})

# %%
sonar[60].value_counts()
# Out:
# 60
# 1    111
# 0     97
# Name: count, dtype: int64

# %%
sonar.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9       10      11      12      13      14      15      16      17  \
# 0  0.2111  0.1609  0.1582  0.2238  0.0645  0.0660  0.2273  0.3100  0.2999
# 1  0.2872  0.4918  0.6552  0.6919  0.7797  0.7464  0.9444  1.0000  0.8874
# 2  0.6194  0.6333  0.7060  0.5544  0.5320  0.6479  0.6931  0.6759  0.7551
# 3  0.1264  0.0881  0.1992  0.0184  0.2261  0.1729  0.2131  0.0693  0.2281
# 4  0.4459  0.4152  0.3952  0.4256  0.4135  0.4528  0.5326  0.7306  0.6193
#
# ...

# %%
sonar.duplicated().sum()
# Out:
# np.int64(0)

# %%
sonar.drop_duplicates().shape
# Out:
# (208, 61)

# %%
#constant and quasi constant column
n_rows=len(sonar)
nunique=sonar.nunique()
constant_cols=nunique[nunique==1].index.tolist()
print("Constant Columns",constant_cols)
# Out:
# Constant Columns []

# %%
quasi=[]
for col in sonar.columns:
    top_freq=sonar[col].value_counts(normalize=True,dropna=False).values[0]
    if top_freq>0.95 and col not in  constant_cols:
        quasi.append(col)
print("Quasi columns (top value more than 95 percent)",quasi)
# Out:
# Quasi columns (top value more than 95 percent) []

# %%
sonar.groupby(60).mean()
# Out:
#           0         1         2         3         4         5         6   \
# 60
# 0   0.022498  0.030303  0.035951  0.041447  0.062028  0.096224  0.114180
# 1   0.034989  0.045544  0.050720  0.064768  0.086715  0.111864  0.128359
#
#           7         8         9         10        11        12        13  \
# 60
# 0   0.117596  0.137392  0.159325  0.174713  0.191589  0.226249  0.268963
# 1   0.149832  0.213492  0.251022  0.289581  0.301459  0.314426  0.320692
#
#           14        15        16        17        18        19        20  \
# 60
# 0   0.307636  0.375611  0.417100  0.448240  0.466762  0.500229  0.542270
# 1   0.331182  0.380999  0.415007  0.455882  0.538062  0.617941  0.667426
#
#           21        22        23        24        25        26        27  \
# 60
# 0   0.569290  0.612959  0.653761  0.668809  0.692762  0.687737  0.673145
# 1   0.672325  0.676701  0.689165  0.681204  0.706075  0.714754  0.712269
#
# ...

# %%
sonar.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9           10          11  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.121747    0.134799    0.178003    0.208259    0.236013    0.250221
# ...

# %% [markdown]
# ### Data Visualaziation

# %%
sns.set_theme(style="darkgrid")

# %%
for col in sonar.columns:
    plt.figure(figsize=(5,3))
    sns.histplot(sonar[col],kde=True)
    plt.title(f"Histplot of {col}")
    plt.xlabel(col)
    plt.ylabel("frequency")
    plt.show()

# %%
fig,axes=plt.subplots(13,5,figsize=(15,8))
axes=axes.flatten()

for i ,col in enumerate(sonar.columns):
    sns.histplot(sonar[col],kde=True,ax=axes[i])
    axes[i].set_title(col,fontsize=8)
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(14,10))
sns.heatmap(sonar.corr(),cmap="coolwarm",annot=True)
plt.show()

# %% [markdown]
# ### Data Preprocessing

# %%
x=sonar.drop(columns=[60])
y=sonar[60]

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=42)

# %%
print("Dataset Shape:",x.shape)
print("Dataset Shape:",X_train.shape)
print("Dataset Shape:",X_test.shape)
# Out:
# Dataset Shape: (208, 60)
# Dataset Shape: (166, 60)
# Dataset Shape: (42, 60)

# %%
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %% [markdown]
# Support Vector Classifier (svc) works well for high dimensional data

# %%
model=SVC()
model.fit(X_train_scaled,y_train)
# Out:
# SVC()

# %%
y_train_pred=model.predict(X_train_scaled)
train_acc=accuracy_score(y_train,y_train_pred)

# %%
train_acc
# Out:
# 0.9698795180722891

# %%
y_test_pred=model.predict(X_test_scaled)
test_acc=accuracy_score(y_test,y_test_pred)

# %%
test_acc
# Out:
# 0.9285714285714286

# %%
print("Classification Report:")
print(classification_report(y_train,y_train_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        77
#            1       1.00      0.94      0.97        89
#
#     accuracy                           0.97       166
#    macro avg       0.97      0.97      0.97       166
# weighted avg       0.97      0.97      0.97       166

# %% [markdown]
# ### Building a Predictive System

# %%
def pedict_object(input_features):
    scaled_features=scaler.transform(input_features)
    #get prediction
    prediction=model.predict(scaled_features)
    if prediction[0]==1:
        print("The object is mine")
    else:
        print("The object is rock")

# %%
X_test.head()
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 103  0.0162  0.0253  0.0262  0.0386  0.0645  0.0472  0.1056  0.1388  0.0598
# 168  0.0015  0.0186  0.0289  0.0195  0.0515  0.0817  0.1005  0.0124  0.1168
# 129  0.1371  0.1226  0.1385  0.1484  0.1776  0.1428  0.1773  0.2161  0.1630
# 182  0.0095  0.0308  0.0539  0.0411  0.0613  0.1039  0.1016  0.1394  0.2592
# 90   0.0126  0.0519  0.0621  0.0518  0.1072  0.2587  0.2304  0.2067  0.3416
#
#          9       10      11      12      13      14      15      16      17  \
# 103  0.1334  0.2969  0.4754  0.5677  0.5690  0.6421  0.7487  0.8999  1.0000
# 168  0.1476  0.2118  0.2575  0.2354  0.1334  0.0092  0.1951  0.3685  0.4646
# 129  0.2067  0.4257  0.5484  0.7131  0.7003  0.6777  0.7939  0.9382  0.8925
# 182  0.3745  0.4229  0.4499  0.5404  0.4303  0.3333  0.3496  0.3426  0.2851
# 90   0.4284  0.3015  0.1207  0.3299  0.5707  0.6962  0.9751  1.0000  0.9293
#
# ...

# %%
y_test.head()
# Out:
# 103    1
# 168    1
# 129    1
# 182    1
# 90     0
# Name: 60, dtype: int64

# %%
X_test.shape
# Out:
# (42, 60)

# %%
import random
arr = np.random.random((1,60))*0.5
test_i=pd.DataFrame(arr,columns=X_test.columns)

sample_prediction=pedict_object(test_i)
print(sample_prediction)
# Out:
# The object is mine
# None
